# %%
import os

import torch
import torch.nn
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader

# OpenCV
import cv2

# plotting
import matplotlib.pyplot as plt
import json

# %% [markdown]
# # Let's Visualise random images and mask of that image from the dataset

# %%
image_path = "/Users/akhil/Documents/Machine learning/Mas-Roads-Dataset/tiff/train/"
mask_path = "/Users/akhil/Documents/Machine learning/Mas-Roads-Dataset/tiff/train_labels/"
images = []
masks = []
for idx, file in enumerate(os.listdir(image_path)):
    images.append(file)
    
for idx, file in enumerate(os.listdir(mask_path)):
    masks.append(file)

images.sort()
mask.sort()

random_samples = random.sample(range(len(images)), k = 4)
random_samples
# Out:
# [758, 885, 809, 977]

# %%
images[random_samples[0]]
# Out:
# '23428585_15.tiff'

# %%
masks[random_samples[0]]
# Out:
# '12178750_15.tif'

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)

# Flatten the axs array for easy indexing
axs = axs.flatten()
for ind, index in enumerate(random_samples):
    if ind > 4:
        break;
    image = cv2.imread(os.path.join(image_path,images[random_samples[index]]))
    mask = cv2.imread(os.path.join(mask_path,masks[random_samples[index]]))

    # Display the image in the next subplot
    axs[ind].imshow(image)
    axs[ind].set_title(f"Image {index}")

    # If you want to display the mask in the same subplot, uncomment the next line
    # axs[ind].imshow(mask, alpha=0.5)  # Adjust alpha for mask transparency

    # Hide axis
    axs[ind].axis('off')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[99], line 9
#       7 if ind > 4:
#       8     break;
# ----> 9 image = cv2.imread(os.path.join(image_path,images[random_samples[index]]))
#      10 mask = cv2.imread(os.path.join(mask_path,masks[random_samples[index]]))
#      12 # Display the image in the next subplot
#
# IndexError: list index out of range

# %%
image = cv2.imread(os.path.join(image_path, image))
mask = cv2.imread(os.path.join(mask_path, mask))

# %%
fig, axs = plt.subplots(1, 2)
axis =  "False"
axs[0].imshow(image)
axs[1].imshow(mask)

# %%
for i
